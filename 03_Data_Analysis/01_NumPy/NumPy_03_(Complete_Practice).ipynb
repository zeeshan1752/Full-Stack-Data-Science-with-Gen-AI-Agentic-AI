# %% [markdown]
# # NumPy

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40])

print(numbers)
# Out:
# [10 20 30 40]

# %% [raw]
# - To install numpy module

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in C:\Users\zeesh\anaconda3\Lib\site-packages (2.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# - To chech version

# %%
np.__version__
# Out:
# '2.4.6'

# %% [markdown]
# ## 1. Python List to NumPy Array

# %%
numbers = [10, 20, 30, 40]

arr = np.array(numbers)

print(arr)
print(type(arr))
# Out:
# [10 20 30 40]
# <class 'numpy.ndarray'>

# %% [markdown]
# ### 1D Array

# %% [markdown]
# A one-dimensional array contains values in a single row.

# %%
arr = np.array([10, 20, 30, 40])

# %%
arr
# Out:
# array([10, 20, 30, 40])

# %% [markdown]
# ### 2D Array
#
# A two-dimensional array contains rows and columns.

# %%
arr = np.array([
    [10, 20],
    [30, 40]
])

print(arr)
# Out:
# [[10 20]
#  [30 40]]

# %% [markdown]
# #### Python List

# %%
numbers = [10, 20, 30, 40]

result = []

for number in numbers:
    result.append(number + 5)

print(result)
# Out:
# [15, 25, 35, 45]

# %% [markdown]
# #### NumPy Array

# %%
numbers = np.array([10, 20, 30, 40, 50])
numbers = numbers + 5
print(numbers)
# Out:
# [15 25 35 45 55]

# %% [markdown]
# Here, NumPy performs the operation directly on all elements. This is called a **vectorized operation**.

# %% [markdown]
# ## 2. Array Properties

# %% [markdown]
# | Property | Meaning |
# |---|---|
# | `ndim` | Number of dimensions |
# | `shape` | Number of rows and columns |
# | `size` | Total number of elements |
# | `dtype` | Data type of elements |

# %%
arr = np.array([
    [10, 20, 30],
    [40, 50, 60]
])

print(arr.ndim)
print(arr.shape)
print(arr.size)
print(arr.dtype)
# Out:
# 2
# (2, 3)
# 6
# int64

# %% [markdown]
# ## 3. Creating NumPy Arrays

# %% [markdown]
# ### `np.array()`

# %%
arr = np.array([1, 2, 3, 4])

print(arr)
# Out:
# [1 2 3 4]

# %% [markdown]
# ### `np.zeros()`

# %% [markdown]
# Creates an array filled with zeros.

# %%
arr = np.zeros(5)

print(arr)
# Out:
# [0. 0. 0. 0. 0.]

# %% [markdown]
# ### `np.ones()`

# %% [markdown]
# Creates an array filled with ones.

# %%
arr = np.ones(4)

print(arr)
# Out:
# [1. 1. 1. 1.]

# %% [markdown]
# ### `np.full()`

# %% [markdown]
# Creates an array filled with a specified value.

# %%
arr = np.full(5, 10)
print(arr)
# Out:
# [10 10 10 10 10]

# %% [markdown]
# ### `np.arange()`

# %% [markdown]
# - Creates values within a given range.
#
# - `np.arange(start, stop, step)`

# %%
arr = np.arange(1, 6)

print(arr)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# ### `np.linspace()`

# %% [markdown]
# Creates a specified number of equally spaced values.

# %%
arr = np.linspace(0, 10, 5)

print(arr)
# Out:
# [ 0.   2.5  5.   7.5 10. ]

# %% [markdown]
# ### `np.eye()`

# %% [markdown]
# Creates an identity matrix.

# %%
arr = np.eye(3)

print(arr)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# ## 4. Array Indexing and Slicing

# %% [markdown]
# ### 1D Indexing

# %%
arr = np.array([10, 20, 30, 40])

print(arr[0])
print(arr[2])
# Out:
# 10
# 30

# %%
arr = np.array([10, 20, 30, 40])

print(arr[-1])
print(arr[-2])
# Out:
# 40
# 30

# %% [markdown]
# ### 2D Indexing

# %% [markdown]
# For a 2D array, we use:
#
# - `array[row, column]`

# %%
arr = np.array([
    [10, 20, 30],
    [40, 50, 60]
])

print(arr[0, 1])
print(arr[1, 2])
# Out:
# 20
# 60

# %% [markdown]
# ### Slicing

# %%
arr = np.array([10, 20, 30, 40, 50])

print(arr[1:4])
# Out:
# [20 30 40]

# %% [markdown]
# ### 2D Slicing

# %%
arr = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

print(arr[0:2, 1:3])
# Out:
# [[20 30]
#  [50 60]]

# %% [markdown]
# ## 5. Array Data Types

# %% [markdown]
# NumPy arrays have a data type called `dtype`.

# %%
arr = np.array([10, 20, 30])

print(arr.dtype)
# Out:
# int64

# %% [markdown]
# ### Specifying Data Type

# %% [markdown]
# We can specify the data type while creating the array.

# %%
arr = np.array([10, 20, 30], dtype=float)

print(arr)
print(arr.dtype)
# Out:
# [10. 20. 30.]
# float64

# %% [markdown]
# ### Changing Data Type Using `astype()`

# %%
arr = np.array([10, 20, 30])

new_arr = arr.astype(float)

print(new_arr)
# Out:
# [10. 20. 30.]

# %% [markdown]
# ## 6. Array Operations

# %% [markdown]
# NumPy allows us to perform mathematical operations directly on arrays.

# %% [markdown]
# ### Addition

# %%
arr = np.array([10, 20, 30])

print(arr + 5)
# Out:
# [15 25 35]

# %% [markdown]
# ### Multiplication

# %%
arr = np.array([10, 20, 30])

print(arr * 2)
# Out:
# [20 40 60]

# %% [markdown]
# ### Division

# %%
arr = np.array([10, 20, 30])

print(arr / 2)
# Out:
# [ 5. 10. 15.]

# %%
arr = np.array([10, 20, 30])

print(arr // 2)
# Out:
# [ 5 10 15]

# %% [markdown]
# ### Operations Between Arrays

# %%
a = np.array([10, 20, 30])
b = np.array([1, 2, 3])

print(a + b)
print(a * b)
# Out:
# [11 22 33]
# [10 40 90]

# %% [markdown]
# ### Comparison Operations

# %%
arr = np.array([10, 20, 30, 40])

print(arr > 20)
# Out:
# [False False  True  True]

# %% [markdown]
# ## 7. Broadcasting

# %% [markdown]
# Broadcasting allows NumPy to perform operations between arrays of compatible shapes.

# %%
arr = np.array([10, 20, 30])

print(arr + 5)
# Out:
# [15 25 35]

# %%
a = np.array([10, 20, 30]) # 3 elements
b = np.array([1, 2, 3, 4]) # 4 elements

print(a + b) # both array must have same shape to perform operation
print(a * b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 4
#       1 a = np.array([10, 20, 30]) # 3 elements
#       2 b = np.array([1, 2, 3, 4]) # 4 elements
#       3
# ----> 4 print(a + b) # both array must have same shape to perform operation
#       5 print(a * b)
#
# ValueError: operands could not be broadcast together with shapes (3,) (4,)

# %%
a = np.array([10, 20, 30]) # 3 elements
b = np.array([1, 2, 3]) # 3 elements

print(a + b)
print(a * b)
# Out:
# [11 22 33]
# [10 40 90]

# %% [markdown]
# ## 8. Mathematical Functions

# %% [markdown]
# ### Square Root

# %%
arr = np.array([4, 9, 16, 25])

print(np.sqrt(arr))
# Out:
# [2. 3. 4. 5.]

# %% [markdown]
# ### Absolute Value

# %%
arr = np.array([-10, 20, -30])

print(np.abs(arr))
# Out:
# [10 20 30]

# %% [markdown]
# ### Rounding

# %%
arr = np.array([2.345, 5.678])

print(np.round(arr, 2))
# Out:
# [2.35 5.68]

# %% [markdown]
# ### Power

# %%
arr = np.array([2, 3, 4])

print(np.power(arr, 2))
# Out:
# [ 4  9 16]

# %% [markdown]
# ### Common Mathematical Functions
#
# - `np.sqrt()`
# - `np.abs()`
# - `np.round()`
# - `np.power()`
# - `np.exp()`
# - `np.log()`

# %% [markdown]
# ## 9. Statistical and Aggregation Functions

# %% [markdown]
# NumPy provides functions to calculate common statistics.

# %% [markdown]
# ### Common Statistical Functions
#
# | Function | Purpose |
# |---|---|
# | `np.sum()` | Finds the total |
# | `np.mean()` | Finds the average |
# | `np.median()` | Finds the middle value |
# | `np.min()` | Finds the smallest value |
# | `np.max()` | Finds the largest value |
# | `np.std()` | Finds standard deviation |
# | `np.var()` | Finds variance |

# %%
marks = np.array([70, 80, 65, 90, 85])

print(np.sum(marks))
print(np.mean(marks))
print(np.median(marks))
print(np.min(marks))
print(np.max(marks))
print(np.std(marks))
print(np.var(marks))
# Out:
# 390
# 78.0
# 80.0
# 65
# 90
# 9.273618495495704
# 86.0

# %% [markdown]
# ### `axis`

# %% [markdown]
# `axis` is useful when working with 2D arrays.
#
# - `axis=0` → works column-wise
# - `axis=1` → works row-wise

# %%
marks = np.array([
    [80, 70, 90],
    [60, 85, 75]
])

print(np.sum(marks, axis=0))
print(np.sum(marks, axis=1))
# Out:
# [140 155 165]
# [240 220]

# %% [markdown]
# ## 10. Boolean Indexing, Masking and Filtering

# %% [markdown]
# Boolean indexing is used to select elements based on a condition.

# %%
marks = np.array([45, 67, 89, 32, 76])

print(marks >= 50)
# Out:
# [False  True  True False  True]

# %% [markdown]
# The Boolean array is called a **Boolean mask**.
#
# We can use this mask to filter values:

# %%
marks = np.array([45, 67, 89, 32, 76])

result = marks[marks >= 50]

print(result)
# Out:
# [67 89 76]

# %% [markdown]
# ### Multiple Conditions

# %%
marks = np.array([45, 67, 89, 32, 76])

result = marks[(marks >= 50) & (marks <= 80)]

print(result)
# Out:
# [67 76]

# %% [markdown]
# ## 11. `np.where()`

# %% [markdown]
# `np.where()` is used to select values or find positions based on a condition.

# %% [markdown]
# ### Find Positions

# %%
marks = np.array([40, 65, 80, 35])

print(np.where(marks >= 50))
# Out:
# (array([1, 2]),)

# %% [markdown]
# The positions `1` and `2` contain values greater than or equal to `50`.

# %% [markdown]
# ### Select Values

# %% [markdown]
# `np.where()` can also select one value when the condition is true and another value when it is false.

# %%
marks = np.array([40, 65, 80, 35])

result = np.where(marks >= 50, "Pass", "Fail")

print(result)
# Out:
# ['Fail' 'Pass' 'Pass' 'Fail']

# %% [markdown]
# ## 12. Array Manipulation

# %% [markdown]
# Array manipulation means changing the structure or form of an array.

# %%
arr = np.arange(1, 7)

new_arr = arr.reshape(2, 3)

print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ### `flatten()`

# %% [markdown]
# Converts a multidimensional array into a 1D array.

# %%
arr = np.array([
    [1, 2],
    [3, 4]
])

print(arr.flatten())
# Out:
# [1 2 3 4]

# %% [markdown]
# ### `ravel()`

# %% [markdown]
# Also converts an array into a 1D form.

# %%
print(arr.ravel())
# Out:
# [1 2 3 4]

# %% [markdown]
# ### Transpose

# %% [markdown]
# Transpose changes rows into columns and columns into rows.

# %%
print(arr.T)
# Out:
# [[1 3]
#  [2 4]]

# %% [markdown]
# ## 13. Joining and Splitting Arrays

# %% [markdown]
# ### `np.concatenate()`

# %% [markdown]
# Joins arrays together.

# %%
a = np.array([1, 2])
b = np.array([3, 4])

result = np.concatenate((a, b))

print(result)
# Out:
# [1 2 3 4]

# %% [markdown]
# ### Other Joining Functions
#
# * `np.concatenate()` – Used to join arrays along an existing axis.
# * `np.stack()` – Used to join arrays along a **new axis**.
# * `np.hstack()` – Used to join arrays **horizontally (column-wise)**.
# * `np.vstack()` – Used to join arrays **vertically (row-wise)**.

# %% [markdown]
# ### `np.split()`

# %% [markdown]
# Splits an array into multiple parts.

# %%
arr = np.array([1, 2, 3, 4])

result = np.split(arr, 2)

print(result)
# Out:
# [array([1, 2]), array([3, 4])]

# %% [markdown]
# ## 14. Sorting and Searching

# %% [markdown]
# ### `np.sort()`

# %% [markdown]
# Sorts an array.

# %%
arr = np.array([40, 10, 30, 20])

print(np.sort(arr))
# Out:
# [10 20 30 40]

# %% [markdown]
# ### `np.argsort()`

# %% [markdown]
# Returns the indexes that would sort the array.

# %%
arr = np.array([40, 10, 30, 20])

print(np.argsort(arr))
# Out:
# [1 3 2 0]

# %% [markdown]
# ### `np.unique()`

# %% [markdown]
# Finds unique values

# %%
arr = np.array([10, 20, 10, 30, 20])

print(np.unique(arr))
# Out:
# [10 20 30]

# %% [markdown]
# ### `np.searchsorted()`

# %% [markdown]
# Finds the position where a value can be inserted while keeping the array sorted.

# %%
arr = np.array([10, 20, 30, 40])

print(np.searchsorted(arr, 25))
# Out:
# 2

# %% [markdown]
# ## 15. Random Numbers and Sampling

# %% [markdown]
# NumPy provides functions for generating random values.

# %% [markdown]
# ### Random Seed

# %% [markdown]
# A seed is used when we want the same random results every time.

# %%
np.random.seed(10)

print(np.random.randint(1, 10, 5))
# Out:
# [5 1 2 1 2]

# %% [markdown]
# ### `np.random.seed()`

# %% [markdown]
# - `seed()` fixes the starting point of random number generation so that the same sequence of random numbers can be generated again.
#
# - `np.random.seed()` is used to get reproducible random results; using the same seed value produces the same sequence of random numbers.

# %% [markdown]
# ### `np.random.rand()`

# %% [markdown]
# Generates random floating-point numbers between `0` and `1`.

# %%
np.random.seed(10)

print(np.random.rand(3))
# Out:
# [0.77132064 0.02075195 0.63364823]

# %% [markdown]
# ### `np.random.randint()`

# %% [markdown]
# Generates random integers.

# %%
np.random.seed(10)

print(np.random.randint(1, 10, 5))
# Out:
# [5 1 2 1 2]

# %% [markdown]
# ### `np.random.choice()`

# %% [markdown]
# Selects random values from an array.

# %%
np.random.seed(10)

arr = np.array([10, 20, 30, 40, 50])

print(np.random.choice(arr, 3))
# Out:
# [20 50 10]

# %% [markdown]
# ## 16. Linear Algebra

# %% [markdown]
# NumPy provides functions for matrix and linear algebra operations.

# %% [markdown]
# ### Matrix Multiplication

# %%
a = np.array([
    [1, 2],
    [3, 4]
])

b = np.array([
    [5, 6],
    [7, 8]
])

result = np.matmul(a, b)

print(result)
# Out:
# [[19 22]
#  [43 50]]

# %% [markdown]
# ### Dot Product

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

result = np.dot(a, b)

print(result)
# Out:
# 32

# %% [markdown]
# ### Other Linear Algebra Operations
#
# * **Matrix transpose** – `np.transpose()`
# * **Matrix inverse** – `np.linalg.inv()`
# * **Determinant** – `np.linalg.det()`
# * **Eigenvalues** – `np.linalg.eigvals()`
# * **Eigenvectors** – `np.linalg.eig()`

# %% [markdown]
# ## 17. Logical and Boolean Functions

# %% [markdown]
# NumPy provides functions for checking and combining conditions.

# %% [markdown]
# ### `np.all()`

# %% [markdown]
# Checks whether all values satisfy a condition.

# %%
arr = np.array([10, 20, 30])

print(np.all(arr > 0))
# Out:
# True

# %% [markdown]
# ### `np.any()`

# %% [markdown]
# Checks whether at least one value satisfies a condition.

# %%
arr = np.array([10, 20, 30])

print(np.any(arr > 25))
# Out:
# True

# %% [markdown]
# ### `np.logical_and()`

# %% [markdown]
# Performs logical AND between two Boolean arrays.

# %%
a = np.array([True, True, False])
b = np.array([True, False, True])

print(np.logical_and(a, b))
# Out:
# [ True False False]

# %% [markdown]
# ### Other Logical Functions
#
# - `np.logical_and()`
# - `np.logical_or()`
# - `np.logical_not()`

# %% [markdown]
# ## 18. Set Operations

# %% [markdown]
# NumPy provides functions for performing set-like operations on arrays.

# %%
a = np.array([1, 2, 3, 4])
b = np.array([3, 4, 5, 6])

# %% [markdown]
# ### Union

# %% [markdown]
# Returns all unique values from both arrays.

# %%
print(np.union1d(a, b))
# Out:
# [1 2 3 4 5 6]

# %% [markdown]
# ### Intersection

# %% [markdown]
# Returns values that are present in both arrays.

# %%
print(np.intersect1d(a, b))
# Out:
# [3 4]

# %% [markdown]
# ### Difference

# %% [markdown]
# Returns values that are present in the first array but not in the second array.

# %%
print(np.setdiff1d(a, b))
# Out:
# [1 2]

# %% [markdown]
# ## 19. Handling Missing and Special Values

# %% [markdown]
# NumPy provides special values such as `np.nan` and `np.inf`.

# %% [markdown]
# ### `np.nan`

# %% [markdown]
# `np.nan` represents a missing or undefined numerical value.

# %%
arr = np.array([10, 20, np.nan, 40])

print(np.isnan(arr))
# Out:
# [False False  True False]

# %% [markdown]
# ### `np.inf`

# %% [markdown]
# `np.inf` represents infinity.

# %%
arr = np.array([10, np.inf, 30])

print(arr)
# Out:
# [10. inf 30.]

# %% [markdown]
# ### `np.isfinite()`

# %% [markdown]
# Checks whether values are finite.

# %%
arr = np.array([10, np.nan, np.inf, 40])

print(np.isfinite(arr))
# Out:
# [ True False False  True]

# %% [markdown]
# ### Common Functions
#
# * `np.isnan()` – Used to **check for NaN (Not a Number) values**.
# * `np.isinf()` – Used to **check for infinite (`∞` or `-∞`) values**.
# * `np.isfinite()` – Used to **check whether values are finite (not NaN or infinity)**.

# %% [markdown]
# ## 20. Copy and View
#
# NumPy arrays can be copied or viewed.

# %% [markdown]
# ### Copy
#
# A copy creates a separate array. Changes made to the copy do not affect the original array.

# %%
arr = np.array([10, 20, 30])

copy_arr = arr.copy()

copy_arr[0] = 100

print(arr)
print(copy_arr)
# Out:
# [10 20 30]
# [100  20  30]

# %% [markdown]
# ### View
#
# A view shares the same underlying data. Changes made to the view can affect the original array.

# %%
arr = np.array([10, 20, 30])

view_arr = arr.view()

view_arr[0] = 100

print(arr)
print(view_arr)
# Out:
# [100  20  30]
# [100  20  30]

# %% [markdown]
# ### Difference
#
# | Copy | View |
# |---|---|
# | Creates a separate array | Shares data with the original |
# | Changes do not affect the original | Changes can affect the original |
# | Uses separate memory | Shares underlying data |

# %% [markdown]
# ## 21. Parameters and Hyperparameters tuning

# %% [markdown]
# ### Parameters
#
# When NumPy uses the default data type automatically.

# %%
import numpy as np

arr = np.array([10, 20, 30])

print(arr.dtype)
# Out:
# int64

# %% [markdown]
# ### Hyperparameters
#
# When the user explicitly changes the data type using the `dtype` parameter.

# %%
import numpy as np

arr = np.array([10, 20, 30], dtype=float)

print(arr.dtype)
# Out:
# float64
