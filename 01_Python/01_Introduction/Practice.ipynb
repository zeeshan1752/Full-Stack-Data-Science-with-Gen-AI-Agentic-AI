# %% [markdown]
# # Task 1 - Practice and test how .ipynb file works

# %%
5
6
# Out:
# 6

# %%
a = 5
b = 6

# %%
a+b
# Out:
# 11

# %%
b-a
# Out:
# 1

# %%
_+2 # _ (underscore) it is used for recent value
# Out:
# 3

# %%
_-6
# Out:
# 5

# %%
8//4 #integer value after division
# Out:
# 2

# %%
8/4 #float value after division
# Out:
# 2.0

# %%
'zeeshan jamshed'
# Out:
# 'zeeshan jamshed'

# %%
k = 90
k1 = 99.99
k2 = "Hyderabad"
print(k, k1, k2)
# Out:
# 90 99.99 Hyderabad

# %%
s = 90
s1 = 99.99
s2 = "Hyderabad"
print(s)
print(s1)
print(s2)
# Out:
# 90
# 99.99
# Hyderabad
