# %% [markdown]
# # Comments

# %%
a = 5
#This is a single line comment
#Use hash for comment
#Python supports both triple - single and double qoutes for multi-line comment
#Comments is mostly used to explain codes
a
# Out:
# 5

# %%
'zeeshan jamshed' #this is my name
# Out:
# 'zeeshan jamshed'

# %%
'''
Myself Zeeshan Jamshed
I'm from Lucknow
'''

a = 4
a
# Out:
# 4
