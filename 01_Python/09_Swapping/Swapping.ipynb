# %% [markdown]
# # Swapping

# %% [markdown]
# ## 1. Using a temp or third variable

# %%
a = 10
b = 50

# %%
temp = a
a = b
b = temp

# %%
a
# Out:
# 50

# %%
b
# Out:
# 10

# %% [markdown]
# ## 2. Using arithmetic operator

# %%
c = 10
d = 50

# %%
c = c + d
d = c - d
c = c - d

# %%
c
# Out:
# 10

# %%
d
# Out:
# 50

# %% [markdown]
# ## 3. Using miltiple assignment

# %%
e = 10
f = 50

# %%
e, f = f, e

# %%
e
# Out:
# 50

# %%
f
# Out:
# 10

# %% [markdown]
# # Common Mistake

# %%
a1 = 10
a2 = 50

# %%
a = b
b = a

# %%
a
# Out:
# 50

# %%
b
# Out:
# 50
